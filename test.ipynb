# %%
import math
import pickle
import shutil
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from neuralprophet import NeuralProphet
from tqdm import tqdm, trange

from constants import (
    DEBUG_FORECAST_FOLDER,
    DEBUG_POSTGRESQL_PARQUET_TRAIN,
    DEBUG_POSTGRESQL_PARQUET_FUTURE,
    PG_LOG_DTYPES,
)
from forecast_metadata import ForecastMD
from generated_forecast_md import GeneratedForecastMD

# %%
pq_files = [Path(DEBUG_POSTGRESQL_PARQUET_TRAIN)]
print(f"Parquet files: {pq_files}")
for pq_file in tqdm(pq_files, desc="Reading Parquet files.", disable=True):
    df = pd.read_parquet(pq_file)
    df["log_time"] = df["log_time"].dt.tz_convert("UTC")
    print(f"{pq_file} has timestamps from {df['log_time'].min()} to {df['log_time'].max()}.")
    df["query_template"] = df["query_template"].replace("", np.nan)
    dropna_before = df.shape[0]
    df = df.dropna(subset=["query_template"])
    dropna_after = df.shape[0]
    print(
        f"Dropped {dropna_before - dropna_after} empty query template rows in {pq_file}. {dropna_after} rows remain."
    )
    
df.head()
# Out:
# Parquet files: [PosixPath('artifacts/tmp/data/train.parquet')]
# artifacts/tmp/data/train.parquet has timestamps from 2022-05-19 02:10:25.683000+00:00 to 2022-05-19 02:10:44.468000+00:00.
# Dropped 33 empty query template rows in artifacts/tmp/data/train.parquet. 121988 rows remain.
#                            log_time       session_id  session_line_num  \
# 29 2022-05-19 02:10:28.659000+00:00  6285a714.219b92                 4
# 30 2022-05-19 02:10:28.660000+00:00  6285a714.219b92                 5
# 31 2022-05-19 02:10:28.660000+00:00  6285a714.219b92                 6
# 32 2022-05-19 02:10:28.661000+00:00  6285a714.219b92                 7
# 33 2022-05-19 02:10:28.677000+00:00  6285a714.219b92                 8
#
#    virtual_transaction_id  transaction_id               query_template  \
# 29                    3/9               0                        BEGIN
# 30                    3/9               0  SET extra_float_digits = $1
# 31                    3/9               0    SET application_name = $1
# 32                    3/9               0                       COMMIT
# 33                   3/10               0      select current_schema()
#
#                   query_params
# 29                          []
# 30                       ['3']
# 31  ['PostgreSQL JDBC Driver']
# 32                          []
# 33                          []

# %%
vids = df.groupby("virtual_transaction_id").size()
vids = vids[(vids >= 5) & (vids <= 20)].index # vids with larger than 5 queries
vids[-20:]
# Out:
# Index(['3/97', '3/970', '3/973', '3/974', '3/976', '3/978', '3/98', '3/981',
#        '3/984', '3/986', '3/987', '3/988', '3/989', '3/99', '3/990', '3/993',
#        '3/994', '3/996', '3/997', '3/999'],
#       dtype='object', name='virtual_transaction_id')

# %%
pd.options.display.max_colwidth = None
for i, vid in enumerate(vids):
  print(vid)
  if i >= 10:
    break
  display(df[df["virtual_transaction_id"] == vid][["query_template", "query_params"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/jiaqidon/noisepage-forecast/test.ipynb Cell 4' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bcmudb-demo4/home/jiaqidon/noisepage-forecast/test.ipynb#ch0000003vscode-remote?line=0'>1</a> pd.options.display.max_colwidth = None
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcmudb-demo4/home/jiaqidon/noisepage-forecast/test.ipynb#ch0000003vscode-remote?line=1'>2</a> for i, vid in enumerate(vids):
#       <a href='vscode-notebook-cell://ssh-remote%2Bcmudb-demo4/home/jiaqidon/noisepage-forecast/test.ipynb#ch0000003vscode-remote?line=2'>3</a>   print(vid)
#       <a href='vscode-notebook-cell://ssh-remote%2Bcmudb-demo4/home/jiaqidon/noisepage-forecast/test.ipynb#ch0000003vscode-remote?line=3'>4</a>   if i >= 10:
#
# NameError: name 'vids' is not defined

# %%
display(df[df["virtual_transaction_id"] == '3/103'][["query_template", "query_params"]])
# Out:
#                                                                                                                                                                                        query_template  \
# 2056                                                                                                                                                                                            BEGIN
# 2057                                                                                                SELECT C_DISCOUNT, C_LAST, C_CREDIT FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_ID = $3
# 2058                                                                                                                                                      SELECT W_TAX FROM warehouse WHERE W_ID = $1
# 2059                                                                                                               SELECT D_NEXT_O_ID, D_TAX FROM district WHERE D_W_ID = $1 AND D_ID = $2 FOR UPDATE
# 2060                                                                                                               UPDATE district SET D_NEXT_O_ID = D_NEXT_O_ID + $1 WHERE D_W_ID = $2 AND D_ID = $3
# 2061                                                                          INSERT INTO oorder (O_ID, O_D_ID, O_W_ID, O_C_ID, O_ENTRY_D, O_OL_CNT, O_ALL_LOCAL) VALUES ($1, $2, $3, $4, $5, $6, $7)
# 2062                                                                                                                           INSERT INTO new_order (NO_O_ID, NO_D_ID, NO_W_ID) VALUES ( $1, $2, $3)
# 2063                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 2064  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 2065                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 2066  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 2067                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 2068  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 2069                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 2070  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 2071                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 2072  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 2073                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 2074  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 2075                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 2076                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 2077                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 2078                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 2079                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 2080                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 2081                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 2082                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 2083                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 2084                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 2085                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 2086                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 2087                                                                                                                                                                                           COMMIT
#
#                                                                                                      query_params
# 2056                                                                                                           []
# 2057                                                                                      ['1.0', '4.0', '155.0']
# 2058                                                                                                      ['1.0']
# 2059                                                                                               ['1.0', '4.0']
# 2060                                                                                          ['1', '1.0', '4.0']
# 2061                                   ['3003.0', '4.0', '1.0', '155.0', '2022-05-07 23:10:52.036', '6.0', '1.0']
# 2062                                                                                     ['3003.0', '4.0', '1.0']
# 2063                                                                                                   ['5158.0']
# 2064                                                                                            ['5158.0', '1.0']
# 2065                                                                                                  ['71863.0']
# 2066                                                                                           ['71863.0', '1.0']
# 2067                                                                                                  ['72303.0']
# 2068                                                                                           ['72303.0', '1.0']
# 2069                                                                                                  ['72861.0']
# 2070                                                                                           ['72861.0', '1.0']
# 2071                                                                                                  ['73190.0']
# 2072                                                                                           ['73190.0', '1.0']
# 2073                                                                                                  ['97959.0']
# 2074                                                                                           ['97959.0', '1.0']
# 2075     ['3003.0', '4.0', '1.0', '1.0', '5158.0', '1.0', '1.0', '92.06999969482422', 'zvbqzvykmjoyewddhablwif ']
# 2076    ['3003.0', '4.0', '1.0', '2.0', '71863.0', '1.0', '6.0', '527.8200073242188', 'eikcjfggbokfsihohdcmwnq ']
# 2077  ['3003.0', '4.0', '1.0', '3.0', '72303.0', '1.0', '10.0', '35.099998474121094', 'skxplaxlroezkvwdkbwrieo ']
# 2078   ['3003.0', '4.0', '1.0', '4.0', '72861.0', '1.0', '3.0', '158.52000427246094', 'poyfedgkzyyvzxlgykuzovo ']
# 2079                ['3003.0', '4.0', '1.0', '5.0', '73190.0', '1.0', '5.0', '144.0', 'bmaotuetcioycokkuannqpw ']
# 2080   ['3003.0', '4.0', '1.0', '6.0', '97959.0', '1.0', '5.0', '257.45001220703125', 'nufkcwrmdzksbevqraheous ']
# 2081                                                                 ['46.0', '1.0', '1', '0.0', '5158.0', '1.0']
# 2082                                                                ['26.0', '6.0', '1', '0.0', '71863.0', '1.0']
# 2083                                                               ['50.0', '10.0', '1', '0.0', '72303.0', '1.0']
# 2084                                                                ['70.0', '3.0', '1', '0.0', '72861.0', '1.0']
# 2085                                                                ['20.0', '5.0', '1', '0.0', '73190.0', '1.0']
# 2086                                                                ['12.0', '5.0', '1', '0.0', '97959.0', '1.0']
# 2087                                                                                                           []

# %%
from constants import DEBUG_FORECAST_FOLDER
import glob, os
from tqdm import tqdm
import pandas as pd

pq_files = glob.glob(os.path.join(DEBUG_FORECAST_FOLDER, "*.parquet"))

# %%
pd.options.display.max_colwidth = None

for pq_file in tqdm(pq_files, desc="Reading Parquet files.", disable=True):
    df = pd.read_parquet(pq_file)
    vids = df.groupby("session_id").size().index

    i = 0
    new_df = pd.DataFrame()
    for vid in vids:
        if i == 10:
            break
        df2 = df[df["session_id"] == vid][["query_template", "query_params"]]
        display(df2)
        if new_df.empty:
            new_df = df2
        else:
            new_df = pd.concat((new_df, df2))
        i += 1
    break

# new_df[:100]
# Out:
#                                                                                                                                                                                      query_template  \
# 0                                                                                                                                                                                             BEGIN
# 1                                                                                                 SELECT C_DISCOUNT, C_LAST, C_CREDIT FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_ID = $3
# 2                                                                                                                                                       SELECT W_TAX FROM warehouse WHERE W_ID = $1
# 3                                                                                                                SELECT D_NEXT_O_ID, D_TAX FROM district WHERE D_W_ID = $1 AND D_ID = $2 FOR UPDATE
# 4                                                                                                                UPDATE district SET D_NEXT_O_ID = D_NEXT_O_ID + $1 WHERE D_W_ID = $2 AND D_ID = $3
# 5                                                                           INSERT INTO oorder (O_ID, O_D_ID, O_W_ID, O_C_ID, O_ENTRY_D, O_OL_CNT, O_ALL_LOCAL) VALUES ($1, $2, $3, $4, $5, $6, $7)
# 6                                                                                                                            INSERT INTO new_order (NO_O_ID, NO_D_ID, NO_W_ID) VALUES ( $1, $2, $3)
# 7                                                                                                                                         SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 8   SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 9                                                                                                                                         SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 10  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 11                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 12  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 13                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 14  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 15                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 16  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 17                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 18  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 19                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 20  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 21                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 22  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 23                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 24                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 25                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 26                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 27                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 28                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 29                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 30                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 31                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 32                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 33                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 34                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 35                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 36                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 37                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 38                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 39                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 40                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 41                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 42                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 43                                                                                                                                                                                           COMMIT
#
#                                                                                                                                                              query_params
# 0                                                            {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 1                                                        {'$1': ''1'', '$2': ''8'', '$3': ''33'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 2                                                           {'$1': ''1'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3                                                          {'$1': ''1'', '$2': ''8'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 4                                                         {'$1': ''1'', '$2': ''1'', '$3': ''8'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 5                           {'$1': ''3079'', '$2': ''8'', '$3': ''8'', '$4': ''33'', '$5': ''2022-05-19 02:10:43.417'', '$6': ''8'', '$7': ''1'', '$8': None, '$9': None}
# 6                                                      {'$1': ''3079'', '$2': ''8'', '$3': ''1'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 7                                                       {'$1': ''68194'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 8                                                      {'$1': ''68194'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 9                                                       {'$1': ''52617'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 10                                                     {'$1': ''52617'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 11                                                      {'$1': ''14524'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 12                                                     {'$1': ''14524'', '$2': ''8'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 13                                                      {'$1': ''25585'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 14                                                     {'$1': ''25585'', '$2': ''8'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 15                                                      {'$1': ''57697'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 16                                                     {'$1': ''57697'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 17                                                      {'$1': ''68238'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 18                                                     {'$1': ''68238'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 19                                                      {'$1': ''62989'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 20                                                     {'$1': ''62989'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 21                                                      {'$1': ''35019'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 22                                                     {'$1': ''35019'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 23   {'$1': ''3079'', '$2': ''1'', '$3': ''1'', '$4': ''8'', '$5': ''35019'', '$6': ''1'', '$7': ''1'', '$8': ''262.92304074295856'', '$9': ''spofkkuqhdvwdnmvkgsizgy ''}
# 24    {'$1': ''3079'', '$2': ''8'', '$3': ''1'', '$4': ''8'', '$5': ''35019'', '$6': ''1'', '$7': ''1'', '$8': ''544.9287920251624'', '$9': ''jwmsizbvpchpibjshpecifv ''}
# 25    {'$1': ''3079'', '$2': ''8'', '$3': ''1'', '$4': ''7'', '$5': ''35019'', '$6': ''8'', '$7': ''1'', '$8': ''923.2631969060211'', '$9': ''bepctoaionldpbdfeazvjay ''}
# 26  {'$1': ''3079'', '$2': ''8'', '$3': ''1'', '$4': ''33'', '$5': ''35019'', '$6': ''1'', '$7': ''8'', '$8': ''162.86762913342415'', '$9': ''faddlioolqnubqnnbbvzgcl ''}
# 27                                                {'$1': ''92'', '$2': ''1'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 28                                                {'$1': ''94'', '$2': ''8'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''8'', '$7': None, '$8': None, '$9': None}
# 29                                               {'$1': ''37'', '$2': ''8'', '$3': ''1'', '$4': ''0'', '$5': ''35019'', '$6': ''33'', '$7': None, '$8': None, '$9': None}
# 30                                               {'$1': ''50'', '$2': ''33'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''8'', '$7': None, '$8': None, '$9': None}
# 31                                               {'$1': ''30'', '$2': ''33'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''8'', '$7': None, '$8': None, '$9': None}
# 32                                                {'$1': ''30'', '$2': ''8'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''8'', '$7': None, '$8': None, '$9': None}
# 33                                                {'$1': ''55'', '$2': ''8'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 34                                                {'$1': ''51'', '$2': ''1'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 35                                               {'$1': ''16'', '$2': ''33'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''8'', '$7': None, '$8': None, '$9': None}
# 36                                                {'$1': ''59'', '$2': ''8'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 37                                                {'$1': ''72'', '$2': ''8'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 38                                                {'$1': ''44'', '$2': ''8'', '$3': ''1'', '$4': ''3'', '$5': ''35019'', '$6': ''8'', '$7': None, '$8': None, '$9': None}
# 39                                                {'$1': ''38'', '$2': ''1'', '$3': ''1'', '$4': ''0'', '$5': ''35019'', '$6': ''8'', '$7': None, '$8': None, '$9': None}
# 40                                                {'$1': ''19'', '$2': ''8'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 41                                                {'$1': ''11'', '$2': ''1'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 42                                               {'$1': ''36'', '$2': ''33'', '$3': ''1'', '$4': ''2'', '$5': ''35019'', '$6': ''8'', '$7': None, '$8': None, '$9': None}
# 43                                                           {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
#                                                                                                                                                                                                                                                     query_template  \
# 44                                                                                                                                                                                                                                                           BEGIN
# 45                                                                                                                                                                                                         UPDATE warehouse SET W_YTD = W_YTD + $1 WHERE W_ID = $2
# 46                                                                                                                                                                    SELECT W_STREET_1, W_STREET_2, W_CITY, W_STATE, W_ZIP, W_NAME FROM warehouse WHERE W_ID = $1
# 47                                                                                                                                                                                          UPDATE district SET D_YTD = D_YTD + $1 WHERE D_W_ID = $2 AND D_ID = $3
# 48                                                                                                                                                     SELECT D_STREET_1, D_STREET_2, D_CITY, D_STATE, D_ZIP, D_NAME FROM district WHERE D_W_ID = $1 AND D_ID = $2
# 49  SELECT C_FIRST, C_MIDDLE, C_ID, C_STREET_1, C_STREET_2, C_CITY, C_STATE, C_ZIP, C_PHONE, C_CREDIT, C_CREDIT_LIM, C_DISCOUNT, C_BALANCE, C_YTD_PAYMENT, C_PAYMENT_CNT, C_SINCE FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_LAST = $3 ORDER BY C_FIRST
# 50                                                                                                                                     UPDATE customer SET C_BALANCE = -$1, C_YTD_PAYMENT = $2, C_PAYMENT_CNT = $3 WHERE C_W_ID = $4 AND C_D_ID = $5 AND C_ID = $6
# 51                                                                                                                                     INSERT INTO history (H_C_D_ID, H_C_W_ID, H_C_ID, H_D_ID, H_W_ID, H_DATE, H_AMOUNT, H_DATA) VALUES ($1,$2,$3,$4,$5,$6,$7,$8)
# 52                                                                                                                                                                                                                                                          COMMIT
#
#                                                                                                                                                                          query_params
# 44                                                                       {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 45                                                      {'$1': ''871.11509164145'', '$2': ''20'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 46                                                                     {'$1': ''20'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 47                                                     {'$1': ''871.11509164145'', '$2': ''20'', '$3': ''2'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 48                                                                   {'$1': ''20'', '$2': ''20'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 49                                                        {'$1': ''20'', '$2': ''3'', '$3': ''ABLEOUGHTPRI'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 50                           {'$1': ''-2358.606966881747'', '$2': ''6719.315691976259'', '$3': ''20'', '$4': ''20'', '$5': ''3'', '$6': ''1019'', '$7': None, '$8': None, '$9': None}
# 51  {'$1': ''3'', '$2': ''20'', '$3': ''1019'', '$4': ''20'', '$5': ''20'', '$6': ''2022-05-19 02:10:43.598'', '$7': ''871.11509164145'', '$8': ''wstwxyo    asqkuompj'', '$9': None}
# 52                                                                       {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
#                                                                                                                                                                                                                                                      query_template  \
# 197                                                                                                                                                                                                                                                           BEGIN
# 198                                                                                                                                                                                                         UPDATE warehouse SET W_YTD = W_YTD + $1 WHERE W_ID = $2
# 199                                                                                                                                                                    SELECT W_STREET_1, W_STREET_2, W_CITY, W_STATE, W_ZIP, W_NAME FROM warehouse WHERE W_ID = $1
# 200                                                                                                                                                                                          UPDATE district SET D_YTD = D_YTD + $1 WHERE D_W_ID = $2 AND D_ID = $3
# 201                                                                                                                                                     SELECT D_STREET_1, D_STREET_2, D_CITY, D_STATE, D_ZIP, D_NAME FROM district WHERE D_W_ID = $1 AND D_ID = $2
# 202  SELECT C_FIRST, C_MIDDLE, C_ID, C_STREET_1, C_STREET_2, C_CITY, C_STATE, C_ZIP, C_PHONE, C_CREDIT, C_CREDIT_LIM, C_DISCOUNT, C_BALANCE, C_YTD_PAYMENT, C_PAYMENT_CNT, C_SINCE FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_LAST = $3 ORDER BY C_FIRST
# 203                                                                                                                                     UPDATE customer SET C_BALANCE = -$1, C_YTD_PAYMENT = $2, C_PAYMENT_CNT = $3 WHERE C_W_ID = $4 AND C_D_ID = $5 AND C_ID = $6
# 204                                                                                                                                     INSERT INTO history (H_C_D_ID, H_C_W_ID, H_C_ID, H_D_ID, H_W_ID, H_DATE, H_AMOUNT, H_DATA) VALUES ($1,$2,$3,$4,$5,$6,$7,$8)
# 205                                                                                                                                                                                                                                                          COMMIT
#
#                                                                                                                                                                         query_params
# 197                                                                     {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 198                                                  {'$1': ''365.08339236147924'', '$2': ''9'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 199                                                                    {'$1': ''9'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 200                                                 {'$1': ''365.08339236147924'', '$2': ''9'', '$3': ''4'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 201                                                                   {'$1': ''9'', '$2': ''9'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 202                                                       {'$1': ''9'', '$2': ''4'', '$3': ''ATIONPRESESE'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 203                             {'$1': ''5116.828105046736'', '$2': ''2350.435636566832'', '$3': ''4'', '$4': ''9'', '$5': ''9'', '$6': ''224'', '$7': None, '$8': None, '$9': None}
# 204  {'$1': ''9'', '$2': ''9'', '$3': ''224'', '$4': ''9'', '$5': ''9'', '$6': ''2022-05-19 02:10:41.554'', '$7': ''365.08339236147924'', '$8': ''wstwxyo    sbzxsibz'', '$9': None}
# 205                                                                     {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
#                                                                                                                             query_template  \
# 3260                                                                                                                                 BEGIN
# 3261                                       SELECT NO_O_ID FROM new_order WHERE NO_D_ID = $1 AND NO_W_ID = $2 ORDER BY NO_O_ID ASC LIMIT $3
# 3262                                                            DELETE FROM new_order WHERE NO_O_ID = $1 AND NO_D_ID = $2 AND NO_W_ID = $3
# 3263                                                             SELECT O_C_ID FROM oorder WHERE O_ID = $1 AND O_D_ID = $2 AND O_W_ID = $3
# 3264                                                   UPDATE oorder SET O_CARRIER_ID = $1 WHERE O_ID = $2 AND O_D_ID = $3 AND O_W_ID = $4
# ...                                                                                                                                    ...
# 3320                                                   UPDATE oorder SET O_CARRIER_ID = $1 WHERE O_ID = $2 AND O_D_ID = $3 AND O_W_ID = $4
# 3321                                         UPDATE order_line SET OL_DELIVERY_D = $1 WHERE OL_O_ID = $2 AND OL_D_ID = $3 AND OL_W_ID = $4
# 3322                                SELECT SUM(OL_AMOUNT) AS OL_TOTAL FROM order_line WHERE OL_O_ID = $1 AND OL_D_ID = $2 AND OL_W_ID = $3
# 3323  UPDATE customer SET C_BALANCE = C_BALANCE + $1, C_DELIVERY_CNT = C_DELIVERY_CNT + $2 WHERE C_W_ID = $3 AND C_D_ID = $4 AND C_ID = $5
# 3324                                                                                                                                COMMIT
#
#                                                                                                                                    query_params
# 3260                               {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3261                            {'$1': ''4'', '$2': ''1'', '$3': ''1'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3262                         {'$1': ''2140'', '$2': ''4'', '$3': ''1'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3263                         {'$1': ''2140'', '$2': ''1'', '$3': ''4'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3264                        {'$1': ''1'', '$2': ''2140'', '$3': ''4'', '$4': ''4'', '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# ...                                                                                                                                         ...
# 3320                        {'$1': ''7'', '$2': ''2140'', '$3': ''1'', '$4': ''1'', '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3321  {'$1': ''2022-05-19 02:10:42.611'', '$2': ''2140'', '$3': ''6'', '$4': ''1'', '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3322                         {'$1': ''2140'', '$2': ''6'', '$3': ''4'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3323       {'$1': ''40154.104071585476'', '$2': ''1'', '$3': ''1'', '$4': ''6'', '$5': ''150'', '$6': None, '$7': None, '$8': None, '$9': None}
# 3324                               {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
#
# [65 rows x 2 columns]
#                                                                                                                                                  query_template  \
# 3325                                                                                                                                                      BEGIN
# 3326                                                          SELECT C_DISCOUNT, C_LAST, C_CREDIT FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_ID = $3
# 3327                                                                                                                SELECT W_TAX FROM warehouse WHERE W_ID = $1
# 3328                                                                         SELECT D_NEXT_O_ID, D_TAX FROM district WHERE D_W_ID = $1 AND D_ID = $2 FOR UPDATE
# 3329                                                                         UPDATE district SET D_NEXT_O_ID = D_NEXT_O_ID + $1 WHERE D_W_ID = $2 AND D_ID = $3
# ...                                                                                                                                                         ...
# 3389  UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 3390  UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 3391  UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 3392  UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 3393                                                                                                                                                     COMMIT
#
#                                                                                                                                  query_params
# 3325                             {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3326                         {'$1': ''1'', '$2': ''9'', '$3': ''54'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3327                            {'$1': ''1'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3328                           {'$1': ''1'', '$2': ''9'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3329                          {'$1': ''1'', '$2': ''1'', '$3': ''1'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# ...                                                                                                                                       ...
# 3389                  {'$1': ''73'', '$2': ''1'', '$3': ''1'', '$4': ''0'', '$5': ''31873'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 3390                  {'$1': ''21'', '$2': ''1'', '$3': ''1'', '$4': ''0'', '$5': ''31873'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 3391                  {'$1': ''55'', '$2': ''1'', '$3': ''1'', '$4': ''0'', '$5': ''31873'', '$6': ''9'', '$7': None, '$8': None, '$9': None}
# 3392  {'$1': ''98'', '$2': ''9.299494736906642'', '$3': ''1'', '$4': ''0'', '$5': ''31873'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 3393                             {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
#
# [69 rows x 2 columns]
#                                                                                                                                                                                                                                                       query_template  \
# 3394                                                                                                                                                                                                                                                           BEGIN
# 3395                                                                                                                                                                                                         UPDATE warehouse SET W_YTD = W_YTD + $1 WHERE W_ID = $2
# 3396                                                                                                                                                                    SELECT W_STREET_1, W_STREET_2, W_CITY, W_STATE, W_ZIP, W_NAME FROM warehouse WHERE W_ID = $1
# 3397                                                                                                                                                                                          UPDATE district SET D_YTD = D_YTD + $1 WHERE D_W_ID = $2 AND D_ID = $3
# 3398                                                                                                                                                     SELECT D_STREET_1, D_STREET_2, D_CITY, D_STATE, D_ZIP, D_NAME FROM district WHERE D_W_ID = $1 AND D_ID = $2
# 3399  SELECT C_FIRST, C_MIDDLE, C_ID, C_STREET_1, C_STREET_2, C_CITY, C_STATE, C_ZIP, C_PHONE, C_CREDIT, C_CREDIT_LIM, C_DISCOUNT, C_BALANCE, C_YTD_PAYMENT, C_PAYMENT_CNT, C_SINCE FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_LAST = $3 ORDER BY C_FIRST
# 3400                                                                                                                                     UPDATE customer SET C_BALANCE = -$1, C_YTD_PAYMENT = $2, C_PAYMENT_CNT = $3 WHERE C_W_ID = $4 AND C_D_ID = $5 AND C_ID = $6
# 3401                                                                                                                                     INSERT INTO history (H_C_D_ID, H_C_W_ID, H_C_ID, H_D_ID, H_W_ID, H_DATE, H_AMOUNT, H_DATA) VALUES ($1,$2,$3,$4,$5,$6,$7,$8)
# 3402                                                                                                                                                                                                                                                          COMMIT
#
#                                                                                                                                                                        query_params
# 3394                                                                   {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3395                                                 {'$1': ''4092.663592825597'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3396                                                                  {'$1': ''1'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3397                                                {'$1': ''4092.663592825597'', '$2': ''1'', '$3': ''1'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3398                                                                 {'$1': ''1'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3399                                                     {'$1': ''1'', '$2': ''1'', '$3': ''PRESPRICALLY'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3400                          {'$1': ''2154.295959439296'', '$2': ''4203.865809875997'', '$3': ''2'', '$4': ''1'', '$5': ''1'', '$6': ''6400'', '$7': None, '$8': None, '$9': None}
# 3401  {'$1': ''2'', '$2': ''1'', '$3': ''6400'', '$4': ''1'', '$5': ''1'', '$6': ''2022-05-19 02:10:42.993'', '$7': ''4092.663592825597'', '$8': ''wstwxyo    edfwgm'', '$9': None}
# 3402                                                                   {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
#                                                                                                                                                                                                                                                       query_template  \
# 3403                                                                                                                                                                                                                                                           BEGIN
# 3404                                                                                                                                                                                                         UPDATE warehouse SET W_YTD = W_YTD + $1 WHERE W_ID = $2
# 3405                                                                                                                                                                    SELECT W_STREET_1, W_STREET_2, W_CITY, W_STATE, W_ZIP, W_NAME FROM warehouse WHERE W_ID = $1
# 3406                                                                                                                                                                                          UPDATE district SET D_YTD = D_YTD + $1 WHERE D_W_ID = $2 AND D_ID = $3
# 3407                                                                                                                                                     SELECT D_STREET_1, D_STREET_2, D_CITY, D_STATE, D_ZIP, D_NAME FROM district WHERE D_W_ID = $1 AND D_ID = $2
# 3408  SELECT C_FIRST, C_MIDDLE, C_ID, C_STREET_1, C_STREET_2, C_CITY, C_STATE, C_ZIP, C_PHONE, C_CREDIT, C_CREDIT_LIM, C_DISCOUNT, C_BALANCE, C_YTD_PAYMENT, C_PAYMENT_CNT, C_SINCE FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_LAST = $3 ORDER BY C_FIRST
# 3409                                                                                                                                      UPDATE customer SET C_BALANCE = $1, C_YTD_PAYMENT = $2, C_PAYMENT_CNT = $3 WHERE C_W_ID = $4 AND C_D_ID = $5 AND C_ID = $6
# 3410                                                                                                                                     INSERT INTO history (H_C_D_ID, H_C_W_ID, H_C_ID, H_D_ID, H_W_ID, H_DATE, H_AMOUNT, H_DATA) VALUES ($1,$2,$3,$4,$5,$6,$7,$8)
# 3411                                                                                                                                                                                                                                                          COMMIT
#
#                                                                                                                                                                        query_params
# 3403                                                                   {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3404                                                 {'$1': ''2167.445678666747'', '$2': ''0'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3405                                                                  {'$1': ''0'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3406                                                {'$1': ''2167.445678666747'', '$2': ''0'', '$3': ''9'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3407                                                                 {'$1': ''0'', '$2': ''9'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3408                                                     {'$1': ''0'', '$2': ''9'', '$3': ''CALLYPRIPRES'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3409                           {'$1': ''37599.84622547856'', '$2': ''6156.066398946365'', '$3': ''2'', '$4': ''0'', '$5': ''9'', '$6': ''478'', '$7': None, '$8': None, '$9': None}
# 3410  {'$1': ''9'', '$2': ''0'', '$3': ''478'', '$4': ''9'', '$5': ''0'', '$6': ''2022-05-19 02:10:43.836'', '$7': ''2167.445678666747'', '$8': ''wstwxyo    mcjzpbe'', '$9': None}
# 3411                                                                   {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
#                                                                                                                                                                                                                                                       query_template  \
# 3412                                                                                                                                                                                                                                                           BEGIN
# 3413                                                                                                                                                                                                         UPDATE warehouse SET W_YTD = W_YTD + $1 WHERE W_ID = $2
# 3414                                                                                                                                                                    SELECT W_STREET_1, W_STREET_2, W_CITY, W_STATE, W_ZIP, W_NAME FROM warehouse WHERE W_ID = $1
# 3415                                                                                                                                                                                          UPDATE district SET D_YTD = D_YTD + $1 WHERE D_W_ID = $2 AND D_ID = $3
# 3416                                                                                                                                                     SELECT D_STREET_1, D_STREET_2, D_CITY, D_STATE, D_ZIP, D_NAME FROM district WHERE D_W_ID = $1 AND D_ID = $2
# 3417  SELECT C_FIRST, C_MIDDLE, C_ID, C_STREET_1, C_STREET_2, C_CITY, C_STATE, C_ZIP, C_PHONE, C_CREDIT, C_CREDIT_LIM, C_DISCOUNT, C_BALANCE, C_YTD_PAYMENT, C_PAYMENT_CNT, C_SINCE FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_LAST = $3 ORDER BY C_FIRST
# 3418                                                                                                                                     UPDATE customer SET C_BALANCE = -$1, C_YTD_PAYMENT = $2, C_PAYMENT_CNT = $3 WHERE C_W_ID = $4 AND C_D_ID = $5 AND C_ID = $6
# 3419                                                                                                                                     INSERT INTO history (H_C_D_ID, H_C_W_ID, H_C_ID, H_D_ID, H_W_ID, H_DATE, H_AMOUNT, H_DATA) VALUES ($1,$2,$3,$4,$5,$6,$7,$8)
# 3420                                                                                                                                                                                                                                                          COMMIT
#
#                                                                                                                                                                       query_params
# 3412                                                                  {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3413                                                {'$1': ''4155.953220352543'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3414                                                                 {'$1': ''1'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3415                                               {'$1': ''4155.953220352543'', '$2': ''1'', '$3': ''3'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3416                                                                {'$1': ''1'', '$2': ''3'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3417                                                 {'$1': ''1'', '$2': ''10'', '$3': ''ATIONABLECALLY'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3418                        {'$1': ''48.14486402559396'', '$2': ''2916.8498691573495'', '$3': ''10'', '$4': ''1'', '$5': ''3'', '$6': ''554'', '$7': None, '$8': None, '$9': None}
# 3419  {'$1': ''3'', '$2': ''1'', '$3': ''554'', '$4': ''3'', '$5': ''1'', '$6': ''2022-05-19 02:10:40.243'', '$7': ''4155.953220352543'', '$8': ''wstwxyo    fuwaul'', '$9': None}
# 3420                                                                  {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
#                                                                                                                                                                                        query_template  \
# 3421                                                                                                                                                                                            BEGIN
# 3422                                                                                                SELECT C_DISCOUNT, C_LAST, C_CREDIT FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_ID = $3
# 3423                                                                                                                                                      SELECT W_TAX FROM warehouse WHERE W_ID = $1
# 3424                                                                                                               SELECT D_NEXT_O_ID, D_TAX FROM district WHERE D_W_ID = $1 AND D_ID = $2 FOR UPDATE
# 3425                                                                                                               UPDATE district SET D_NEXT_O_ID = D_NEXT_O_ID + $1 WHERE D_W_ID = $2 AND D_ID = $3
# 3426                                                                          INSERT INTO oorder (O_ID, O_D_ID, O_W_ID, O_C_ID, O_ENTRY_D, O_OL_CNT, O_ALL_LOCAL) VALUES ($1, $2, $3, $4, $5, $6, $7)
# 3427                                                                                                                           INSERT INTO new_order (NO_O_ID, NO_D_ID, NO_W_ID) VALUES ( $1, $2, $3)
# 3428                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 3429  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 3430                                                                                                                                        SELECT I_PRICE, I_NAME , I_DATA FROM item WHERE I_ID = $1
# 3431  SELECT S_QUANTITY, S_DATA, S_DIST_01, S_DIST_02, S_DIST_03, S_DIST_04, S_DIST_05, S_DIST_06, S_DIST_07, S_DIST_08, S_DIST_09, S_DIST_10 FROM stock WHERE S_I_ID = $1 AND S_W_ID = $2 FOR UPDATE
# 3432                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3433                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3434                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3435                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3436                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3437                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3438                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3439                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3440                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3441                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3442                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3443                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3444                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3445                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3446                                 INSERT INTO order_line (OL_O_ID, OL_D_ID, OL_W_ID, OL_NUMBER, OL_I_ID, OL_SUPPLY_W_ID, OL_QUANTITY, OL_AMOUNT, OL_DIST_INFO) VALUES ($1,$2,$3,$4,$5,$6,$7,$8,$9)
# 3447                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 3448                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 3449                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 3450                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 3451                                        UPDATE stock SET S_QUANTITY = $1 , S_YTD = S_YTD + $2, S_ORDER_CNT = S_ORDER_CNT + $3, S_REMOTE_CNT = S_REMOTE_CNT + $4 WHERE S_I_ID = $5 AND S_W_ID = $6
# 3452                                                                                                                                                                                           COMMIT
#
#                                                                                                                                                                              query_params
# 3421                                                                         {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3422                                                                   {'$1': ''1'', '$2': ''1'', '$3': ''1869'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3423                                                                        {'$1': ''1'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3424                                                                       {'$1': ''1'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3425                                                                   {'$1': ''-232'', '$2': ''1'', '$3': ''1'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3426                                      {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1869'', '$5': ''2022-05-19 02:10:37.807'', '$6': ''8'', '$7': ''1'', '$8': None, '$9': None}
# 3427                                                                   {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3428                                                                    {'$1': ''45442'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3429                                                                   {'$1': ''45442'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3430                                                                    {'$1': ''49900'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3431                                                                   {'$1': ''49900'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3432                  {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''9'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''418.2160771826929'', '$9': ''yohjuklgrohzezmtvvrqnsw ''}
# 3433                   {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''9'', '$7': ''9'', '$8': ''98.3706042196843'', '$9': ''kyfqwjshndnauyulruojand ''}
# 3434  {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''9'', '$5': ''49900'', '$6': ''1'', '$7': ''1.458326233503734'', '$8': ''562.3830641660594'', '$9': ''xuuappwoccbqnbavbiergio ''}
# 3435                 {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''12.489995954265057'', '$9': ''lzmbpdpazytpggebtkgcepj ''}
# 3436                 {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''183.07259475769112'', '$9': ''ghjammlpvyarlijsxhrqyjb ''}
# 3437                  {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''8'', '$8': ''612.8411257181468'', '$9': ''jgpgdqcuswurfvtqkxhhkdn ''}
# 3438                 {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''154.08206461369343'', '$9': ''lfplncpkqmibtuveggkpgog ''}
# 3439                 {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''161.91702769232336'', '$9': ''nkmzyrlqanbodnyorqboyyp ''}
# 3440                 {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''452.61119145018336'', '$9': ''emuihqsimduvpklxbvujvrh ''}
# 3441                  {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''38.53573726185359'', '$9': ''scefwfpijlvtvrbhiegibyy ''}
# 3442                   {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''93.4549084584472'', '$9': ''ttrvarhxyqeytwwjppwztyu ''}
# 3443                  {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''525.3877791799529'', '$9': ''jelhpqprcwehirgjixppzuq ''}
# 3444                  {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''183.7184277546795'', '$9': ''akymusszmhywkazoyohysib ''}
# 3445                   {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''2'', '$5': ''49900'', '$6': ''1'', '$7': ''1'', '$8': ''723.370458720622'', '$9': ''oxkotcnsehirfeumliiumiz ''}
# 3446                 {'$1': ''3061'', '$2': ''1'', '$3': ''1'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': ''2'', '$8': ''228.79954716128228'', '$9': ''zmcfxbuuvhjhjvjiknvrqge ''}
# 3447                                                           {'$1': ''73'', '$2': ''2'', '$3': ''-232'', '$4': ''0'', '$5': ''49900'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 3448                                                           {'$1': ''31'', '$2': ''1'', '$3': ''-232'', '$4': ''0'', '$5': ''49900'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 3449                                                           {'$1': ''78'', '$2': ''2'', '$3': ''-232'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 3450                                                           {'$1': ''98'', '$2': ''1'', '$3': ''-232'', '$4': ''1'', '$5': ''49900'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 3451                                                           {'$1': ''98'', '$2': ''1'', '$3': ''-232'', '$4': ''0'', '$5': ''49900'', '$6': ''1'', '$7': None, '$8': None, '$9': None}
# 3452                                                                         {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
#                                                                                                                                                                                                                                      query_template  \
# 3453                                                                                                                                                                                                                                          BEGIN
# 3454                                                                                                                                                                                        UPDATE warehouse SET W_YTD = W_YTD + $1 WHERE W_ID = $2
# 3455                                                                                                                                                   SELECT W_STREET_1, W_STREET_2, W_CITY, W_STATE, W_ZIP, W_NAME FROM warehouse WHERE W_ID = $1
# 3456                                                                                                                                                                         UPDATE district SET D_YTD = D_YTD + $1 WHERE D_W_ID = $2 AND D_ID = $3
# 3457                                                                                                                                    SELECT D_STREET_1, D_STREET_2, D_CITY, D_STATE, D_ZIP, D_NAME FROM district WHERE D_W_ID = $1 AND D_ID = $2
# 3458  SELECT C_FIRST, C_MIDDLE, C_LAST, C_STREET_1, C_STREET_2, C_CITY, C_STATE, C_ZIP, C_PHONE, C_CREDIT, C_CREDIT_LIM, C_DISCOUNT, C_BALANCE, C_YTD_PAYMENT, C_PAYMENT_CNT, C_SINCE FROM customer WHERE C_W_ID = $1 AND C_D_ID = $2 AND C_ID = $3
# 3459                                                                                                                    UPDATE customer SET C_BALANCE = -$1, C_YTD_PAYMENT = $2, C_PAYMENT_CNT = $3 WHERE C_W_ID = $4 AND C_D_ID = $5 AND C_ID = $6
# 3460                                                                                                                    INSERT INTO history (H_C_D_ID, H_C_W_ID, H_C_ID, H_D_ID, H_W_ID, H_DATE, H_AMOUNT, H_DATA) VALUES ($1,$2,$3,$4,$5,$6,$7,$8)
# 3461                                                                                                                                                                                                                                         COMMIT
#
#                                                                                                                                                                          query_params
# 3453                                                                     {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3454                                                  {'$1': ''1929.2926003643217'', '$2': ''1'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3455                                                                    {'$1': ''1'', '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3456                                                 {'$1': ''1929.2926003643217'', '$2': ''1'', '$3': ''6'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3457                                                                   {'$1': ''1'', '$2': ''6'', '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3458                                                                {'$1': ''1'', '$2': ''6'', '$3': ''643'', '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}
# 3459                             {'$1': ''2812.533312562009'', '$2': ''4435.752587185615'', '$3': ''2'', '$4': ''1'', '$5': ''1'', '$6': ''956'', '$7': None, '$8': None, '$9': None}
# 3460  {'$1': ''1'', '$2': ''1'', '$3': ''643'', '$4': ''1'', '$5': ''1'', '$6': ''2022-05-19 02:10:30.19'', '$7': ''1929.2926003643217'', '$8': ''wstwxyo    yhmubmfli'', '$9': None}
# 3461                                                                     {'$1': None, '$2': None, '$3': None, '$4': None, '$5': None, '$6': None, '$7': None, '$8': None, '$9': None}

# %%
import re

# %%
# query_template = """
# SELECT COUNT(DISTINCT (S _I_ID)) AS STOCK_COUNT F ROM order_line, stock WH ERE OL_W_ID = $1 AND OL_D_ID = $2 AND OL_O_ID < $3 AND OL_O_ID >= $4 AND S_W_ID = $5 AND S_I_ID = OL_I_ID AND S_QUANTITY < $6
# """

# query_template = 'SELECT C_DISCOUNT, C_LAST, C_CREDIT FROM WHERE customer C_W_ID = $1 AND C_D_ID = $2 AND C_ID = $3'

# query_template = 'UPDATE warehouse SET W_YTD = W_YTD + $1 WHERE W_ID = $2'

# query_template = "UPDATE customer SET C_BALANCE = $1, C_YTD_PAYMENT = $2, C_PAYMENT_CNT = $3, C_DATA = $4 WHERE C_W_ID = $5 AND C_D_ID = $ 6 AND C_ID = $7"

query_template = "SELECT NO_O_ID FROM new_order WHERE NO_D_ID = $1 AND NO_W_ID = $2 ORDER BY NO_O_ID ASC LIMIT $3"

query_template = 'UPDATE customer SET C_BALANCE = -$1, C_YTD_PAYMENT = $2, C_PAYMENT_CNT = $3 WHERE C_W_ID = $4 AND C_D_ID = $5 AND C_ID = $6'

r = re.compile(r"([\S]+) (?:=|>=|<=|>|<) (?:\S+(?: \+ )?)?\$\d+")
print(r.findall(query_template))

# r2 = re.compile(r"(\S+) \$\d+")
# print(r2.findall(query_template))
# Out:
# ['C_BALANCE', 'C_YTD_PAYMENT', 'C_PAYMENT_CNT', 'C_W_ID', 'C_D_ID', 'C_ID']

# %%
query_template = "INSERT INTO history (H_C_D_ID, H_C_W_ID, H_C_ID, H_D_ID, H_W_ID, H_DATE, H_AMOUNT, H_DATA) VALUES ($1,$2,$3,$4,$5,$6,$7,$8)"

query_template = "INSERT INTO oorder (O_ID , O_D_ID, O_W_ID, O_C_ID, O_ENTRY_D, O_OL_CNT, O_ALL_LOCAL) VALUES ($1, $2, $3, $4, $5, $6, $7)"

r = re.compile(r"\(([^\$]+)\)")
cols = r.findall(query_template)[0]
print(cols)
cols.split(", ")
# Out:
# O_ID , O_D_ID, O_W_ID, O_C_ID, O_ENTRY_D, O_OL_CNT, O_ALL_LOCAL
# ['O_ID ', 'O_D_ID', 'O_W_ID', 'O_C_ID', 'O_ENTRY_D', 'O_OL_CNT', 'O_ALL_LOCAL']
